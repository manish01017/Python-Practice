# %%
class car:
  def __init__(self,windows,doors,enginetype):
    self.windows=windows
    self.doors=doors
    self.enginetype=enginetype
  def self_driving(self): ##self represents the instance of car (Car1,car2)
    print("This car runs on {}".format(self.enginetype))

# %%
car1=car(3,4,"petrol")
car2=car(4,5,"diesel")

# %%
car2.enginetype
# Out:
# 'diesel'

# %%
car2.self_driving()
# Out:
# This car runs on diesel

# %% [markdown]
# **Exception Handling**

# %%
try:
  a=int(input("Enter number 1"))
  b=int(input("Enter Number 2"))
  c=a/b
  d=a*b
except ZeroDivisionError:
  print("Please enter the number greater than 0")
except Exception as ex:
  print(ex)
else: # the block will not run if there's exception
  print(c)
  print(d)
finally: ## comes to this block even when there's an exception
  print(c)
  print(d)
  print("It's done")
# Out:
# Enter number 11
# Enter Number 20
# Please enter the number greater than 0
# 2.0
# 2
# It's done

# %% [markdown]
# **CUSTOM EXCEPTION**

# %%
class Error(Exception): ##Inherit Exception class into Error
  pass

class dobexception(Error): ##Create Custom exception
  pass

# %%
try:
  a=int(input("Enter Date of Birth"))
  age=2023-a
  if age<20 & age>30:
    print('Your age is valid. You can be admitted')
  else:
    raise dobexception  ##raise Custom exception
except dobexception:
  print("You can't apply as your age is not valid")
finally:
  print("Thanks for logging in  and providing details")
# Out:
# Enter Date of Birth1987
# You can't apply as your age is not valid
# Thanks for logging in  and providing details

# %% [markdown]
# **Class method**
# *used to update the class variables so that the instance can use the updated value**

# %%
class car:
  base_price=100000
  def __init__(self,windows,door,enginetype):
    self.windows=windows
    self.doors=door
    self.enginetype=enginetype
  @classmethod
  def new_base_price(cls,inflation): ##cls refers to the class not the instance (used in methods)
    cls.base_price=cls.base_price+ cls.base_price*inflation

# %%
car1=car(4,3,"petrol")

# %%
car1.base_price
# Out:
# 100000

# %%
car.new_base_price(0.10) ## called by class, can be called by class object as python does not implement any restrictions.

# %%
car1.base_price
# Out:
# 110000.0

# %%
car2=car(4,3,"diesel")

# %%
car2.base_price
# Out:
# 110000.0

# %% [markdown]
# **Private Protected and Public Variables**
#
# *Public : Can be accessed and modified from  anywhere*
#
# *Private: Cannot be accessed and modified out side the class (declared by __variablename*
#
# *Protected : Can be accessed and modified by the sub class inheriting the parent class (represented by _variable name)

# %% [markdown]
# **Public Variables**

# %%
class Car:
  def __init__(self,doors,windows,enginetype):
    self.windows=windows ##Public variables
    self.doors=doors
    self.enginetype=enginetype
  def self_drive(self):
    print("The Car has {} doors".format(self.doors))

# %%
audi=Car(4,3,"diesel")

# %%
audi.doors
# Out:
# 4

# %%
audi.doors=6 ##Updating the value of public variable

# %%
audi.doors
# Out:
# 6

# %%
dir(audi) ##For seeing the variables linked to the instance
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'enginetype',
#  'self_drive',
#  'windows']

# %% [markdown]
# **Protected**

# %%
class Car:
  def __init__(self,doors,windows,enginetype):
    self._windows=windows ##Protected variables
    self._doors=doors
    self._enginetype=enginetype
  def self_drive(self):
    print("The Vehicle has {} doors".format(self.doors))

# %%
Car1=Car(4,3,"petrol")

# %%
Car1._doors=4 ## Python do not place any restrictions on updating the protected variables but as a developer you should update it from the sub class inheriting this class

# %%
Car1._doors
# Out:
# 4

# %%
dir(Car1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_doors',
#  '_enginetype',
#  '_windows',
#  'self_drive']

# %%
##Creating Sub class inheriting the parent class
class Truck(Car):
  def __init__(self,doors,windows,enginetype,horsepower):
    super().__init__(windows,doors,enginetype) ##inheriting the variables of the parent class using Super() and calling the INIT constructor from parent class
    self.horsepower=horsepower

# %%
Truck1=Truck(4,3,"diesel",1000)

# %%
dir(Truck1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_doors',
#  '_enginetype',
#  '_windows',
#  'horsepower',
#  'self_drive']

# %%
Truck1._doors=5

# %%
dir(Truck1)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_doors',
#  '_enginetype',
#  '_windows',
#  'horsepower',
#  'self_drive']

# %% [markdown]
# **Private**

# %%
class Car:
  def __init__(self,doors,windows,enginetype):
    self.__windows=windows ##Private variables
    self.__doors=doors
    self.__enginetype=enginetype
  def self_drive(self):
    print("The Vehicle has {} doors".format(self.doors))

# %% [markdown]
# **Assert Statement**
#
# *used to check the logical expression, give Assertionerror if the logical expression is false*

# %%
try:
  a=int(input("Enter the Number"))
  assert a%2==0
  print("The number is even")
except AssertionError:
        print("The number is odd")
# Out:
# Enter the Number3
# The number is odd

# %% [markdown]
# **ITERATORS ,ITERABLES, GENERATORS**
#
# *Iterators: uses dynamic memory allocation of elements, called by iter keyword and can be traversed using next keyword*
#
# *Generators: A function is used to create a generator, similar to iterator and uses yield function to store the local variables*

# %%
##Iterables

lst=[1,2,3,4,5,6]

for i in lst:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
##Iterator

iterator=iter(lst)

# %%
next(iterator) #used to traverse the elements and memory is initialised one by one
# Out:
# 3

# %%
##Problem
def square(n):
  for i in range(n):
    return i  # will return only first value

# %%
square(3)
# Out:
# 0

# %%
##Generator
def square(n):
  for i in range(n):
    yield i**2 #Saves the local variable in each iteration

# %%
for i  in square(3):
  print(i)
# Out:
# 0
# 1
# 4

# %% [markdown]
# **Decorator**
#
# *Calling a function and passing other function as parameter*

# %%
def welcome(func):
  def sub_welcome():
    print ("This is Manish's Google collab")
    func()
    print('THanks for coding')
  return sub_welcome()

# %%
@welcome ## Decorator (passing this function as an argument to the welcome function)
def wel():
  print("Welcome here")
# Out:
# This is Manish's Google collab
# Welcome here
# THanks for coding

# %% [markdown]
# ** =,copy(),deepcopy()**

# %%
list1=[1,2,3,4,5,6]
list2=list1 ##Both list 1 and list 2 points to the same memory location

# %%
list2[1]=1

# %%
list2
# Out:
# [1, 1, 3, 4, 5, 6]

# %%
list1 ##any change in list2 will change list1 as well and vice versa
# Out:
# [1, 1, 3, 4, 5, 6]

# %%
list1=[1,2,3,4,5,6]
list2=list1.copy()

# %%
list1[1]=1

# %%
list1
# Out:
# [1, 1, 3, 4, 5, 6]

# %%
list2 # No change in list 2 as it allocates a single dimension list to different location
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list1=[[1,2,3,4],[5,6,7,8]]

# %%
list2=list1.copy()

# %%
list1[0][1]=100

# %%
list2 ##In case of nested list, if the elements of  a single list in a nested list are updated , it will be updated in the copied list as well
# Out:
# [[1, 100, 3, 4], [5, 6, 7, 8]]

# %%
list1.append([7,8,9,0]) ##Adding another list in List1
list1
# Out:
# [[1, 100, 3, 4], [5, 6, 7, 8], [7, 8, 9, 0], [7, 8, 9, 0]]

# %%
list2 ## Changes are not reflected if another list is added
# Out:
# [[1, 100, 3, 4], [5, 6, 7, 8]]

# %%
import copy as cp
list1=[[1,2,3,4],[5,6,7,8]]
list2=cp.deepcopy(list1)

# %%
list1[0][1]=100
list1
# Out:
# [[1, 100, 3, 4], [5, 6, 7, 8]]

# %%
list2 ## No change seen in the elements of the list
# Out:
# [[1, 2, 3, 4], [5, 6, 7, 8]]

# %% [markdown]
# **EVAL FUNCTION**
# *EVal :  evaluates python expressions which are returned as string*

# %% [markdown]
# **How does eval work**
#
# 1. Parse Python expression
# 2. Compile into a byte code
# 3. Evaluate the python expression
# 4. Return the result

# %%
##Syntax
##eval(expression, global variable,local variable)

# %%
eval("x+y",{"x":5,"y":5},{})
# Out:
# 10
